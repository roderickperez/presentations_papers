# %% [markdown]
# # Frac Focus Data Analytics Demo
# **Fracturabilidad y Análisis de datos en Yacimientos No Convencionales**
#
# Webinar: EAGE IPN
#
# Roderick Perez
# Junio, 26, 2020

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import Libraries</a></span></li><li><span><a href="#Load-data-file:-FracFocusRegistry_1.csv" data-toc-modified-id="Load-data-file:-FracFocusRegistry_1.csv-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load data file: FracFocusRegistry_1.csv</a></span></li><li><span><a href="#Explorar-los-datos" data-toc-modified-id="Explorar-los-datos-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Explorar los datos</a></span><ul class="toc-item"><li><span><a href="#Header-del-archivo" data-toc-modified-id="Header-del-archivo-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Header del archivo</a></span></li><li><span><a href="#Cuantas-filas-y-columnas-hay-en-el-archivo" data-toc-modified-id="Cuantas-filas-y-columnas-hay-en-el-archivo-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Cuantas filas y columnas hay en el archivo</a></span></li><li><span><a href="#Archivo-completo" data-toc-modified-id="Archivo-completo-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Archivo completo</a></span></li></ul></li><li><span><a href="#Plot-data" data-toc-modified-id="Plot-data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Plot data</a></span></li><li><span><a href="#pandas_ui" data-toc-modified-id="pandas_ui-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>pandas_ui</a></span><ul class="toc-item"><li><span><a href="#Importar-libreria" data-toc-modified-id="Importar-libreria-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Importar libreria</a></span></li><li><span><a href="#Importar-datos" data-toc-modified-id="Importar-datos-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Importar datos</a></span></li><li><span><a href="#dataFrame" data-toc-modified-id="dataFrame-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>dataFrame</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Load data file: FracFocusRegistry_1.csv

# %%
df = pd.read_csv("C:/Users/RODERICK/Documents/UnconventionalReservoirsImages/\KansasProdData/oil_leases_1980_1989_short.csv")

# %% [markdown]
# ## Explorar los datos

# %% [markdown]
# ### Header del archivo

# %%
df.head()
# Out:
#     LEASE_KID   LEASE  DOR_CODE                        API_NUMBER    FIELD  \
# 0  1001135839  SNYDER  122608.0  15-131-20143, 15-131-20089-0002   KANASKA
# 1  1001135839  SNYDER  122608.0  15-131-20143, 15-131-20089-0002   KANASKA
# 2  1001135839  SNYDER  122608.0  15-131-20143, 15-131-20089-0002   KANASKA
# 3  1001135839  SNYDER  122608.0  15-131-20143, 15-131-20089-0002   KANASKA
# 4  1001135839  SNYDER  122608.0  15-131-20143, 15-131-20089-0002   KANASKA
#
#   PRODUCING_ZONE                  OPERATOR  COUNTY  TOWNSHIP TWN_DIR  ...  \
# 0  Lansing Group  Elk Oil Enterprises, LLC  Nemaha         1       S  ...
# 1  Lansing Group  Elk Oil Enterprises, LLC  Nemaha         1       S  ...
# 2  Lansing Group  Elk Oil Enterprises, LLC  Nemaha         1       S  ...
# 3  Lansing Group  Elk Oil Enterprises, LLC  Nemaha         1       S  ...
# 4  Lansing Group  Elk Oil Enterprises, LLC  Nemaha         1       S  ...
#
# ...

# %% [markdown]
# ### Cuantas filas y columnas hay en el archivo

# %%
df.shape
# Out:
# (3867, 21)

# %% [markdown]
# ### Archivo completo

# %%
df
# Out:
#        LEASE_KID            LEASE  DOR_CODE                        API_NUMBER  \
# 0     1001135839           SNYDER  122608.0  15-131-20143, 15-131-20089-0002
# 1     1001135839           SNYDER  122608.0  15-131-20143, 15-131-20089-0002
# 2     1001135839           SNYDER  122608.0  15-131-20143, 15-131-20089-0002
# 3     1001135839           SNYDER  122608.0  15-131-20143, 15-131-20089-0002
# 4     1001135839           SNYDER  122608.0  15-131-20143, 15-131-20089-0002
# ...          ...              ...       ...                               ...
# 3862  1001139294  CULBERTSON-ADAM  127700.0
# 3863  1001139294  CULBERTSON-ADAM  127700.0
# 3864  1001139294  CULBERTSON-ADAM  127700.0
# 3865  1001139294  CULBERTSON-ADAM  127700.0
# 3866  1001139294  CULBERTSON-ADAM  127700.0
#
#         FIELD PRODUCING_ZONE                    OPERATOR       COUNTY  \
# 0     KANASKA  Lansing Group    Elk Oil Enterprises, LLC       Nemaha
# ...

# %% [markdown]
# ## Plot data

# %%
x = df['LATITUDE']
y = df['LONGITUDE']

# %%
plt.scatter(x,y, c='g')
plt.show()

# %%
x = df['LATITUDE']
y = df['LONGITUDE']
s=df['PRODUCTION']

# %%
plt.scatter(x,y,s=s)
plt.show()

# %% [markdown]
# ## pandas_ui
# La libreria de ```pandas_ui``` permite manejar y explorar los datos de una forma mas amigable para el usuario, basado en ```pandas```. Es bastante util para preparar los datos antes de realizar alguna prediccion de Machine Learning, asi como *data wrangling* y explorar los datos de forma facil y sencilla.
#
# Existen otras librerias que tienen funciones similares como ```bamboolib```, pero lamentablemente son pagas.

# %% [markdown]
# ### Importar libreria

# %%
from pandas_ui import *

# %% [markdown]
# ### Importar datos

# %%
pandas_ui("C:/Users/RODERICK/Documents/UnconventionalReservoirsImages/\KansasProdData/oil_leases_1980_1989_short2.csv")

# %% [markdown]
# ### dataFrame

# %%
get_df()
# Out:
#       LEASE                        API_NUMBER                  OPERATOR  \
# 0    SNYDER  15-131-20143, 15-131-20089-0002   Elk Oil Enterprises, LLC
# 1    SNYDER  15-131-20143, 15-131-20089-0002   Elk Oil Enterprises, LLC
# 2    SNYDER  15-131-20143, 15-131-20089-0002   Elk Oil Enterprises, LLC
# 3    SNYDER  15-131-20143, 15-131-20089-0002   Elk Oil Enterprises, LLC
# 4    SNYDER  15-131-20143, 15-131-20089-0002   Elk Oil Enterprises, LLC
# ..      ...                               ...                       ...
# 177    MERZ                                                Encorp, Inc.
# 178    MERZ                                                Encorp, Inc.
# 179    MERZ                                                Encorp, Inc.
# 180    MERZ                                                Encorp, Inc.
# 181    MERZ                                                Encorp, Inc.
#
#       LATITUDE  LONGITUDE MONTH-YEAR PRODUCT  WELLS  PRODUCTION
# ...
